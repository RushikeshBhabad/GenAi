# %% [markdown]
# <a href="https://colab.research.google.com/github/RushikeshBhabad/GenAi/blob/main/Document_Summarizer_using_Llamaindex.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install llama-index llama-index-llms-groq llama-index-embeddings-huggingface

# %%
import os

# %%
GROQ_API_KEY = "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"

# %%
os.environ["GROQ_API_KEY"] =GROQ_API_KEY

# %%
import nest_asyncio

nest_asyncio.apply()

# %%
from llama_index.core import SimpleDirectoryReader
from llama_index.core import SummaryIndex
from llama_index.llms.groq import Groq
from llama_index.core.node_parser import SentenceSplitter
from llama_index.core import Settings
from llama_index.embeddings.huggingface import HuggingFaceEmbedding

# %%
llm = Groq(model = "llama-3.3-70b-versatile")

Settings.llm = llm
Settings.embed_model = HuggingFaceEmbedding()
# Out:
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# modules.json:   0%|          | 0.00/349 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/124 [00:00<?, ?B/s]
# README.md:   0%|          | 0.00/90.8k [00:00<?, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/52.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/684 [00:00<?, ?B/s]
# ...

# %%
# Loading the documents
documents = SimpleDirectoryReader(input_files=["/content/Resume21211.pdf"]).load_data()

# %%
len(documents)
# Out:
# 1

# %%
documents[0]
# Out:
# Document(id_='0985baf5-1f22-4f15-92c1-5d67711ef665', embedding=None, metadata={'page_label': '1', 'file_name': 'Resume21211.pdf', 'file_path': '/content/Resume21211.pdf', 'file_type': 'application/pdf', 'file_size': 104959, 'creation_date': '2025-04-25', 'last_modified_date': '2025-04-25'}, excluded_embed_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], excluded_llm_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], relationships={}, metadata_template='{key}: {value}', metadata_separator='\n', text_resource=MediaResource(embeddings=None, data=None, text='Rushikesh Bhabad\n/envel⌢perushikeshbhabad2005@gmail.com — +91 8806799368 — Pune, Maharashtra, India\n/linkedinRushikesh Bhabad\nEducation\nPune Institute of Computer Technology CGPA: 9.86\nBachelor of Engineering in Computer Engineering, 2nd Year Ongoing Ongoing\nK.V.N Naik College 84.5%\nHigher Seconda
# ...

# %%
splitter = SentenceSplitter(chunk_size=1500)
nodes = splitter.get_nodes_from_documents(documents)

# %%
summary_index = SummaryIndex(nodes)

"""
SummaryIndex stores the summaries of your document chunks (nodes) in a tree-like structure
It builds a tree structure of summaries from your nodes.
Each node's text is summarized.
These summaries are combined recursively into a higher-level summary. """
# Out:
# "\nIt builds a tree structure of summaries from your nodes.\nEach node's text is summarized.\nThese summaries are combined recursively into a higher-level summary. "

# %%
summary_query_engine = summary_index.as_query_engine(
    response_mode="tree_summarize",
    use_async=True,
)

# %%
response = summary_query_engine.query(" Summarize the give document  ")

# %%
print(response)
# Out:
# The document appears to be a resume of an individual named Rushikesh Bhabad. It highlights his education, technical skills, and projects. He is currently pursuing a Bachelor of Engineering in Computer Engineering and has a strong foundation in programming languages, development technologies, and AI/ML libraries.
#
# The document also showcases his experience with various projects, including a rental platform, a QR-based museum ticket booking system, and an AI-powered financial assistant. Additionally, it mentions his certifications, problem-solving achievements, and extracurricular activities, such as participating in coding contests, mentoring students, and volunteering for social causes. Overall, the document presents a comprehensive overview of Rushikesh's academic background, technical expertise, and personal interests.
